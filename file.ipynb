# %%
import pandas as pd
list =pd.Series([1,2,3,4,5])
#print(list)

dataframe = pd.DataFrame({'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Age': [25, 30, 35, 40, 45],
                          'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'], 
                          'Salary': [50000, 60000, 70000, 80000, 90000]})
#print(dataframe)

dataframe2= pd.DataFrame({"A":[45,56,67,78,89],"B":[78,89,90,100,110 ]})
#print(dataframe2)

dataframe3=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'])
print(dataframe3)

import numpy as np
dataframe4 = pd.DataFrame(np.random.rand(5, 3), columns=['X', 'Y', 'Z'])
print(dataframe4)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9
#           X         Y         Z
# 0  0.753878  0.496745  0.709788
# 1  0.978124  0.100880  0.613115
# 2  0.843322  0.441489  0.388075
# 3  0.860834  0.521622  0.741300
# 4  0.209743  0.314842  0.278238
